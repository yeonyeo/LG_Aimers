# %% [markdown]
# <a href="https://colab.research.google.com/github/yeonyeo/LG_Aimers/blob/main/08_22_submission.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import glob
import re
import random
import numpy as np
import pandas as pd
from datetime import timedelta

import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm

# %%
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
set_seed(42)

# %%
LOOKBACK, PREDICT = 28, 7
BATCH_SIZE, EPOCHS = 16, 40
LR = 1e-3
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def _read_train():
    path = '/content/drive/MyDrive/open/train/train.csv'
    if not os.path.exists(path):
        path = './train.csv'
    df = pd.read_csv(path)
    df['영업일자'] = pd.to_datetime(df['영업일자'])
    return df

# %%
def _dow_one_hot(dates: np.ndarray) -> np.ndarray:
    dows = pd.to_datetime(dates).weekday.values if hasattr(dates, "values") else pd.to_datetime(dates).weekday
    out = np.zeros((len(dates), 7), dtype=np.float32)
    for i, d in enumerate(dows):
        out[i, int(d)] = 1.0
    return out

# %%
# ✅ 공휴일 제외 요일별 중앙값
def same_dow_median_from_last28(dates_28: np.ndarray, values_28: np.ndarray, horizon=7, holiday_mask=None):
    dates_28 = pd.to_datetime(dates_28)
    if holiday_mask is None:
        holiday_mask = np.zeros(len(dates_28), dtype=bool)

    med = {}
    for dow in range(7):
        mask = (dates_28.weekday == dow) & (~holiday_mask)  # ✅ 공휴일 제외
        arr = values_28[mask]
        if len(arr) > 0:
            med[dow] = float(np.median(arr))
    overall = float(np.median(values_28[~holiday_mask])) if np.any(~holiday_mask) else float(np.median(values_28))

    last_date = dates_28.max()
    preds = []
    for h in range(1, horizon+1):
        dow = int((last_date + timedelta(days=h)).weekday())
        preds.append(med.get(dow, overall))
    return np.array(preds, dtype=np.float32)

# %%
def postprocess_from_last28(yhat: np.ndarray, last28_vals: np.ndarray, eps_floor=1.0, cap_quantile=99, cap_scale=1.2):
    yhat = np.maximum(yhat, 0.0)
    yhat = np.where(yhat == 0.0, eps_floor, yhat)
    if len(last28_vals) > 0:
        cap = np.percentile(last28_vals, cap_quantile) * cap_scale
        if np.isfinite(cap) and cap > 0:
            yhat = np.minimum(yhat, cap)
    return yhat

# %%
holidays = pd.to_datetime([
    "2023-01-01","2023-03-01","2023-05-05","2023-05-27","2023-08-15",
    "2023-09-28","2023-09-29","2023-09-30","2023-10-03","2023-10-09",
    "2023-12-25","2024-01-01","2024-02-09","2024-02-10","2024-02-11","2024-02-12",
    "2024-03-01","2024-04-10","2024-05-05","2024-05-06","2024-05-15",
    "2024-06-06"
])

# %%
def add_features(df):
    df['is_weekend'] = (df['영업일자'].dt.weekday >= 5).astype(int)
    df['is_holiday'] = df['영업일자'].isin(holidays).astype(int)
    return df

# %%
class MultiOutputLSTM(nn.Module):
    def __init__(self, input_dim=10, hidden_dim=64, num_layers=2, output_dim=7, dropout=0.1):
        super().__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1])
        return out

# %%
class MultiOutputGRU(nn.Module):
    def __init__(self, input_dim=10, hidden_dim=64, num_layers=2, output_dim=7, dropout=0.1):
        super().__init__()
        self.gru = nn.GRU(input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        out, _ = self.gru(x)
        out = self.fc(out[:, -1])
        return out

# %%
def train_model(train_df: pd.DataFrame, model_type="lstm"):
    trained = {}
    for key, g in tqdm(train_df.groupby('영업장명_메뉴명'), desc=f'Training {model_type.upper()} (per item)'):
        g = g.sort_values('영업일자').copy()
        if len(g) < LOOKBACK + PREDICT:
            continue

        scaler = MinMaxScaler()
        qty = g[['매출수량']].values.astype(np.float32)
        qty_scaled = scaler.fit_transform(qty)

        dows = _dow_one_hot(g['영업일자'].values)
        feats = np.concatenate([qty_scaled, dows,
                                g[['is_weekend','is_holiday']].values.astype(np.float32)], axis=1)  # (N,10)

        X_list, Y_list = [], []
        for i in range(len(g) - LOOKBACK - PREDICT + 1):
            X = feats[i:i+LOOKBACK]    # (28,10)
            y = qty_scaled[i+LOOKBACK:i+LOOKBACK+PREDICT, 0]
            X_list.append(X)
            Y_list.append(y)

        X_train = torch.tensor(np.stack(X_list)).float().to(DEVICE)
        y_train = torch.tensor(np.stack(Y_list)).float().to(DEVICE)

        if model_type == "lstm":
            model = MultiOutputLSTM(input_dim=10, output_dim=PREDICT).to(DEVICE)
        else:
            model = MultiOutputGRU(input_dim=10, output_dim=PREDICT).to(DEVICE)

        opt = torch.optim.Adam(model.parameters(), lr=LR)
        criterion = nn.MSELoss()

        model.train()
        for epoch in range(EPOCHS):
            idx = torch.randperm(X_train.size(0), device=DEVICE)
            for i in range(0, X_train.size(0), BATCH_SIZE):
                b = idx[i:i+BATCH_SIZE]
                xb, yb = X_train[b], y_train[b]
                pred = model(xb)
                loss = criterion(pred, yb)
                opt.zero_grad()
                loss.backward()
                opt.step()

        trained[key] = {'model': model.eval(), 'scaler': scaler}
    return trained

# %%
def predict(test_df, trained_models: dict, model_type: str, test_prefix: str, alpha=0.6):
    results = []
    for key, g in test_df.groupby('영업장명_메뉴명'):
        if key not in trained_models: continue
        g = g.sort_values('영업일자').copy()
        if len(g) < LOOKBACK: continue

        model = trained_models[key]['model']
        scaler = trained_models[key]['scaler']

        last28_vals = g['매출수량'].values[-LOOKBACK:].astype(np.float32)
        last28_dates = pd.to_datetime(g['영업일자']).values[-LOOKBACK:]

        x_qty_scaled = scaler.transform(last28_vals.reshape(-1,1))
        x_dow = _dow_one_hot(last28_dates)
        x_other = g[['is_weekend','is_holiday']].values[-LOOKBACK:].astype(np.float32)
        x_input = np.concatenate([x_qty_scaled, x_dow, x_other], axis=1)[None, ...]

        with torch.no_grad():
            pred_scaled = model(torch.tensor(x_input).float().to(DEVICE)).squeeze(0).cpu().numpy()

        restored = [scaler.inverse_transform([[s]])[0,0] for s in pred_scaled]
        restored = np.maximum(restored, 0.0)

        dow_med = same_dow_median_from_last28(last28_dates, last28_vals, horizon=PREDICT)
        blended = alpha * restored + (1 - alpha) * dow_med
        blended = postprocess_from_last28(blended, last28_vals)

        pred_dates = [f"{test_prefix}+{i+1}일" for i in range(PREDICT)]
        for d, val in zip(pred_dates, blended.tolist()):
            results.append({'영업일자': d, '영업장명_메뉴명': key, '매출수량': val})
    return pd.DataFrame(results)

# %%
def ensemble_predict(test_df, trained_lstm, trained_gru, test_prefix):
    lstm_pred = predict(test_df, trained_lstm, "lstm", test_prefix, alpha=0.6)
    gru_pred = predict(test_df, trained_gru, "gru", test_prefix, alpha=0.6)
    merged = lstm_pred.copy()
    merged['매출수량'] = (lstm_pred['매출수량'] + gru_pred['매출수량']) / 2
    return merged

# %%
# =====================
# Submission
# =====================
def convert_to_submission_format(pred_df: pd.DataFrame, sample_submission: pd.DataFrame):
    pred_df['영업일자'] = pred_df['영업일자'].astype(str)
    pred_df['영업장명_메뉴명'] = pred_df['영업장명_메뉴명'].astype(str)
    pred_dict = dict(zip(zip(pred_df['영업일자'], pred_df['영업장명_메뉴명']), pred_df['매출수량']))
    final_df = sample_submission.copy()
    for row_idx in final_df.index:
        date = final_df.loc[row_idx, '영업일자']
        for col in final_df.columns[1:]:
            final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
    return final_df

# %%
def main():
    train_df = _read_train()                # ✅ train.csv Colab 경로로 읽기
    train_df = add_features(train_df)

    trained_lstm = train_model(train_df, model_type="lstm")
    trained_gru = train_model(train_df, model_type="gru")

    all_preds = []
    test_files = sorted(glob.glob('/content/drive/MyDrive/open/test/TEST_*.csv'))   # ✅ test 파일 경로
    for path in test_files:
        test_df = pd.read_csv(path)
        test_df['영업일자'] = pd.to_datetime(test_df['영업일자'])
        test_df = add_features(test_df)
        test_prefix = re.search(r'(TEST_\d+)', os.path.basename(path)).group(1)
        pred_df = ensemble_predict(test_df, trained_lstm, trained_gru, test_prefix)
        all_preds.append(pred_df)

    full_pred_df = pd.concat(all_preds, ignore_index=True) if len(all_preds) else pd.DataFrame(columns=['영업일자','영업장명_메뉴명','매출수량'])

    sample_path = '/content/drive/MyDrive/open/sample_submission.csv'   # ✅ Colab 경로
    sample = pd.read_csv(sample_path)
    submission = convert_to_submission_format(full_pred_df, sample)
    submission.to_csv('/content/drive/MyDrive/open/0822submission.csv', index=False, encoding='utf-8-sig')  # ✅ 저장경로

if __name__ == "__main__":
    main()
# Out:
# Training LSTM (per item): 100%|██████████| 193/193 [10:24<00:00,  3.23s/it]
# Training GRU (per item): 100%|██████████| 193/193 [09:46<00:00,  3.04s/it]
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.457031679581261' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.42153916318828' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.914883642215715' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7941260188817978' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2538713386991223' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.41186599144239716' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.8372329307839455' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7623233537202825' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.36575978994369507' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6618041360182395' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.38825099056211143' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8344205011600107' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.041817734756274' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.83876866116661' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.708674494792901' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6999440625334952' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4659462581131886' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8558904591536991' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8147909237721684' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6986365549367923' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.3225512214734786' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6890875749426635' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.559564903798804' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.4284716671617391' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.6430708114947317' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.181036151303223' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.017780781206101' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.9512532100454925' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.0306101432260832' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.9698032524510007' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1482172411599296' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.019591693656938' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.21422088944582807' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '26.623081540431137' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6052441386805731' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4658033798588546' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.549311837008005' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12.883980473529238' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7596058955847338' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6062659978516437' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.2763604943387118' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.2213390943753989' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.4105363784257996' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.07179460381277496' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4771124578382837' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5873115145671549' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.915728135875706' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.80642322321007' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.3337551784933511' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.0890034013315795' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5558329324734738' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6495824139596342' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.44880075756309157' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.9686950924344728' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.3464580580856051' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8743167387372499' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3179855593299292' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.45821341297855' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.239488636863694' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '15.950398363733285' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.632320381618147' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.745393151622062' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.238836777542926' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.42841589876699515' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7178272604942322' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4870287937287703' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.15393210718136865' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4219907697738594' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.699038345345221' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.23041535868621832' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.3806316984397791' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3303508809770928' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5868976508312105' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5033151293307104' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.700024333595505' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.742835542134842' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3927022846727883' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.849029095288258' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.271853425563474' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6283280383299583' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8878365768875478' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2832965498180227' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.2610681544164706' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.8472836003517035' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7140516545161111' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6362681124726501' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.253549354763724' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.74824275648989' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9989860631827694' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5182171285152435' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.655144710530649' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.626910978355177' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5694615599593288' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.2715690046548843' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.3860687971115112' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '15.213362312316894' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5835495584325883' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8593099202267086' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.0810612668367654' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.9765423701279548' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.17459527925863028' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '180.5898396494611' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.419856032430589' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '47.90443815564538' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.446821451187134' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.315952281804672' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.4684030847727333' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.135318905904566' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5908140779910375' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3067812559967864' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.4747471660375595' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.14954181836420838' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.3984766975499184' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5246041944279954' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8811461522748266' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.948894598748736' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0296156764030455' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5296719895449882' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2419455221375804' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5323488667607308' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.055065500736236575' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.0761592797935009' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.11225333511829376' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.1526333659887314' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.1398322086086211' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.3538599368328599' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.052562836557626724' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5009286478161812' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.148156102332981' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.43643806115814765' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.33842511956616883' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.3711548566818237' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.31638045137553733' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5361303104700009' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.1880909078244797' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9973065778011063' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.4618803482687369' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.07579192889356826' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.897593897652808' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.538843822479248' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.35421032826342' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5014765494121816' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# ...
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.704097218145034' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2629506840959956' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5745923930809469' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '21.267205879068136' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4182116539464302' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.2533682151263283' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '17.487988087058056' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.6535967172555655' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.2015462731925766' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.833948373534747' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.824277930863925' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9350376919740999' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.55786936490934' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3042688689234376' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.118088396860166' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3646881199168264' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.2768929174494526' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.526530248337257' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.9187003029345027' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.97599983215332' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.397034160864643' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.569900444214046' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.6898170844837237' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.151998996734619' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '19.712389429332276' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.813200944151619' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.561286515982722' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.189313023190463' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.0590754080728595' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.386076187566385' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '29.428081599211495' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '13.179659596424909' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '33.54018490492746' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.485943094733358' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '26.87695815574576' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '23.725394563825194' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12.357221698358474' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '100.78258845864006' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '47.6260970731506' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.165799982737756' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '50.860525105579946' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12.266613910597158' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '32.72952537974785' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12.106295457208804' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14.66373919654671' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.951706878185818' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /tmp/ipython-input-3230395132.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.09399356245994567' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
